# %% [markdown]
# # Web Scraping
#
# Scrape the reviews of BA from https://www.airlinequality.com/airline-reviews/british-airways%5D

# %%
! pip install pyarrow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.8/dist-packages (9.0.0)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.8/dist-packages (from pyarrow) (1.21.6)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from collections import defaultdict
import numpy as np

# %% [markdown]
# ### Scrape function

# %%
def df_from_parse(parsed_content):
    """
    Returns a dataframe of the revies given a html parse of the scraped page

        Parameters:
            parsed_content (parsed html): Beautiful Soup parsing of html

        Returns:
            df (dataframe): Dataframe of the review text, scores and route.

    """
    # Scrape the parsec content for aricles
    articles = parsed_content.find_all("article", {"itemprop":"review"})

    n = len(articles)

    def def_value():
        return [np.nan] * n

    df_dict = defaultdict(def_value)


    for i, article in enumerate(articles):
        # Find the review text
        paragraph = article.find_all("div", {"class": "text_content"})
        df_dict['reviews'][i] = paragraph[0].get_text()

        # Get overall rating
        rating_query = article.find_all('span',{"itemprop":"ratingValue"})
        if len(rating_query) > 0:
            df_dict['overall_rating'][i] = rating_query[0].string

        # Find the revie ratings
        review_ratings = article.find_all("table", {"class": "review-ratings"})

        # each tr contains a review rating name and value via the num of stars
        for x in review_ratings[0].find_all("tr"):
            name_tag, value_tag = x.find_all("td")
            name = name_tag.string.lower()

            if value_tag['class'] == ['review-rating-stars', 'stars']:
                filled_stars = value_tag.find_all('span',{"class":"star fill"})

                # Sometimes the stars row can be empty, ensure this is not the case
                if len(filled_stars) > 0:
                    value = max([x.string for x in filled_stars])
                else:
                    value = np.nan

            else:
                value = value_tag.string

            df_dict[name][i] = value

    df = pd.DataFrame.from_dict(df_dict)
    return df

# %% [markdown]
# ### Scraping Loop

# %%
base_url = "https://www.airlinequality.com/airline-reviews/british-airways"
pages = 35
page_size = 100

reviews = []

dfs = [None] * pages

for i in range(1, pages + 1):

    print(f"Scraping page {i}")

    # Create URL to collect links from paginated data
    url = f"{base_url}/page/{i}/?sortby=post_date%3ADesc&pagesize={page_size}"
    print(url)

    # Collect HTML data from this page
    response = requests.get(url)

    # Parse content
    content = response.content
    parsed_content = BeautifulSoup(content, 'html.parser')
    dfs[i-1] = df_from_parse(parsed_content)
# Out:
# Scraping page 1
# https://www.airlinequality.com/airline-reviews/british-airways/page/1/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 2
# https://www.airlinequality.com/airline-reviews/british-airways/page/2/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 3
# https://www.airlinequality.com/airline-reviews/british-airways/page/3/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 4
# https://www.airlinequality.com/airline-reviews/british-airways/page/4/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 5
# https://www.airlinequality.com/airline-reviews/british-airways/page/5/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 6
# https://www.airlinequality.com/airline-reviews/british-airways/page/6/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 7
# https://www.airlinequality.com/airline-reviews/british-airways/page/7/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 8
# https://www.airlinequality.com/airline-reviews/british-airways/page/8/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 9
# https://www.airlinequality.com/airline-reviews/british-airways/page/9/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 10
# https://www.airlinequality.com/airline-reviews/british-airways/page/10/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 11
# https://www.airlinequality.com/airline-reviews/british-airways/page/11/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 12
# https://www.airlinequality.com/airline-reviews/british-airways/page/12/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 13
# https://www.airlinequality.com/airline-reviews/british-airways/page/13/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 14
# https://www.airlinequality.com/airline-reviews/british-airways/page/14/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 15
# https://www.airlinequality.com/airline-reviews/british-airways/page/15/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 16
# https://www.airlinequality.com/airline-reviews/british-airways/page/16/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 17
# https://www.airlinequality.com/airline-reviews/british-airways/page/17/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 18
# https://www.airlinequality.com/airline-reviews/british-airways/page/18/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 19
# https://www.airlinequality.com/airline-reviews/british-airways/page/19/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 20
# https://www.airlinequality.com/airline-reviews/british-airways/page/20/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 21
# https://www.airlinequality.com/airline-reviews/british-airways/page/21/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 22
# https://www.airlinequality.com/airline-reviews/british-airways/page/22/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 23
# https://www.airlinequality.com/airline-reviews/british-airways/page/23/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 24
# https://www.airlinequality.com/airline-reviews/british-airways/page/24/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 25
# https://www.airlinequality.com/airline-reviews/british-airways/page/25/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 26
# https://www.airlinequality.com/airline-reviews/british-airways/page/26/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 27
# https://www.airlinequality.com/airline-reviews/british-airways/page/27/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 28
# https://www.airlinequality.com/airline-reviews/british-airways/page/28/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 29
# https://www.airlinequality.com/airline-reviews/british-airways/page/29/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 30
# https://www.airlinequality.com/airline-reviews/british-airways/page/30/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 31
# https://www.airlinequality.com/airline-reviews/british-airways/page/31/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 32
# https://www.airlinequality.com/airline-reviews/british-airways/page/32/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 33
# https://www.airlinequality.com/airline-reviews/british-airways/page/33/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 34
# https://www.airlinequality.com/airline-reviews/british-airways/page/34/?sortby=post_date%3ADesc&pagesize=100
# Scraping page 35
# https://www.airlinequality.com/airline-reviews/british-airways/page/35/?sortby=post_date%3ADesc&pagesize=100

# %% [markdown]
# ### Save Scraped Data

# %%
# Concatenate all the pages into one df
df = pd.concat(dfs,axis=0, ignore_index=True)
df.columns = df.columns.str.replace(" ","_")

# Save the file
file_path = '/content/drive/MyDrive/Colab Notebooks/BA/data'
df.to_parquet(file_path+"/reviews.parquet")

# %% [markdown]
# ### Evaluate

# %%
df[df.overall_rating.isnull()]
# Out:
#                                                 reviews overall_rating  \
# 2879  Cabin crew polite unfortunately BA ran out of ...            NaN
# 3012  Phoenix to London - outbound a wonderful and e...            NaN
# 3034  On past experience I chose BA for our long hau...            NaN
# 3268  LHR-CPH-LHR Business Class. This is a joke. Sc...            NaN
# 3295  I flew with British Airways with my mother fro...            NaN
#
#      aircraft type_of_traveller       seat_type route date_flown seat_comfort  \
# 2879      NaN               NaN   Economy Class   NaN        NaN            3
# 3012      NaN               NaN     First Class   NaN        NaN            1
# 3034      NaN               NaN   Economy Class   NaN        NaN            3
# 3268      NaN               NaN  Business Class   NaN        NaN            1
# 3295      NaN               NaN   Economy Class   NaN        NaN            1
#
#      cabin_staff_service food_&_beverages inflight_entertainment  \
# 2879                   5                1                      1
# 3012                   5                4                      2
# 3034                   3                2                      1
# 3268                   1                1                      1
# 3295                   3                1                      1
#
#      ground_service wifi_&_connectivity value_for_money recommended
# 2879            NaN                 NaN               2          no
# 3012            NaN                 NaN               2          no
# 3034            NaN                 NaN               3          no
# 3268            NaN                 NaN               1          no
# 3295            NaN                 NaN               1          no

# %% [markdown]
# ### Test

# %%
import_df = pd.read_parquet(file_path+"/reviews.parquet")
import_df
# Out:
#                                                 reviews overall_rating  \
# 0     ✅ Trip Verified |  A rather empty and quiet fl...              9
# 1     ✅ Trip Verified |  Easy check in and staff mem...              9
# 2     ✅ Trip Verified |  Being a silver flyer and bo...              1
# 3     Not Verified |  I find BA incredibly tacky and...              3
# 4     ✅ Trip Verified |  Flew ATL to LHR 8th Jan 202...              4
# ...                                                 ...            ...
# 3453  LHR-HKG on Boeing 747 - 23/08/12. Much has bee...              4
# 3454  LHR to HAM. Purser addresses all club passenge...              9
# 3455  My son who had worked for British Airways urge...              5
# 3456  London City-New York JFK via Shannon on A318 b...              4
# 3457  SIN-LHR BA12 B747-436 First Class. Old aircraf...              4
#
#             aircraft type_of_traveller        seat_type  \
# 0       Boeing 787-8    Family Leisure    Economy Class
# 1     Boeing 777-200    Couple Leisure   Business Class
# 2               None      Solo Leisure    Economy Class
# 3               None      Solo Leisure  Premium Economy
# 4     Boeing 777-200    Family Leisure    Economy Class
# ...              ...               ...              ...
# 3453            None              None    Economy Class
# 3454            None              None   Business Class
# 3455            None              None    Economy Class
# 3456            None              None  Premium Economy
# 3457            None              None      First Class
#
#                                   route     date_flown seat_comfort  \
# 0                    London to Tel Aviv  December 2022            4
# 1          London Heathrow to Cape Town   January 2023            3
# 2                     Gatwick to Dublin   January 2023            3
# 3     London Heathrow to Athens Greece      April 2022            3
# 4                     Atlanta to London   January 2023            1
# ...                                 ...            ...          ...
# 3453                               None           None            2
# 3454                               None           None            4
# 3455                               None           None         None
# 3456                               None           None            1
# 3457                               None           None            4
#
#      cabin_staff_service food_&_beverages inflight_entertainment  \
# 0                      5                4                      3
# 1                      5                5                      5
# 2                      5             None                   None
# 3                      4                1                      1
# 4                      1                1                      3
# ...                  ...              ...                    ...
# 3453                   3                2                      3
# 3454                   5                4                   None
# 3455                None             None                   None
# 3456                   3                5                   None
# 3457                   5                5                      2
#
#      ground_service wifi_&_connectivity value_for_money recommended
# 0                 4                   4               5         yes
# 1                 4                   5               4         yes
# 2                 1                None               1          no
# 3                 3                   1               1          no
# 4                 1                None               2          no
# ...             ...                 ...             ...         ...
# 3453           None                None               3          no
# 3454           None                None               3         yes
# 3455           None                None               4         yes
# 3456           None                None               1          no
# 3457           None                None               2          no
#
# [3458 rows x 15 columns]

# %%
del import_df
